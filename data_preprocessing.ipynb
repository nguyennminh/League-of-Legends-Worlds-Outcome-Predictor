# %%
import pandas as pd
import glob

# %%
# combines all csv in datasets folder into a single csv file

all_files = glob.glob("datasets/*.csv")

dfs = []
for file in all_files:
    df = pd.read_csv(file)
    dfs.append(df)

combined_df = pd.concat(dfs, ignore_index=True)
combined_df.to_csv("combined_dataset.csv", index=False)
# Out:
# /var/folders/d1/2s6wmgwj39b_bcrm9kmlwqsr0000gn/T/ipykernel_52332/179071226.py:5: DtypeWarning: Columns (2) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv(file)
# /var/folders/d1/2s6wmgwj39b_bcrm9kmlwqsr0000gn/T/ipykernel_52332/179071226.py:5: DtypeWarning: Columns (2) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv(file)
# /var/folders/d1/2s6wmgwj39b_bcrm9kmlwqsr0000gn/T/ipykernel_52332/179071226.py:5: DtypeWarning: Columns (2) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv(file)
# /var/folders/d1/2s6wmgwj39b_bcrm9kmlwqsr0000gn/T/ipykernel_52332/179071226.py:5: DtypeWarning: Columns (2) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv(file)
